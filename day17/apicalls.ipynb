# %% [markdown]
# <a href="https://colab.research.google.com/github/somyaknotfound/data-science/blob/main/day17/apicalls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests as rq
response = rq.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','popularity', 'vote_average' , 'vote_count']]

# %%
df.head(2)
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     45.9678
# 1  Spanning the years 1945 to 1955, a chronicle o...     35.3030
#
#    vote_average  vote_count
# 0         8.713       29436
# 1         8.700       22218

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
  response = rq.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','popularity', 'vote_average' , 'vote_count']]
  df = pd.concat([df, temp_df], ignore_index=True)
